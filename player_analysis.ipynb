# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import scipy

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import plotly.express as px

from datetime import datetime
from scipy import stats

#Set Display options
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

pd.options.display.float_format = '{:.2f}'.format

# %%
all_players = pd.read_csv(r"./data/all_players.csv" , parse_dates= ["news_added"]) 
player_gameweek_history = pd.read_csv(r"./data/player_past_history/merged_data.csv") 
all_teams = pd.read_csv(r"./data/all_teams.csv")
all_events = pd.read_csv(r"./data/all_events.csv" , parse_dates= ["deadline_time"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-67b98d99a1b6> in <module>
#       1 all_players = pd.read_csv(r"./data/all_players.csv" , parse_dates= ["news_added"])
# ----> 2 player_gameweek_history = pd.read_csv(r"./data/player_past_history/player_gameweek_history.csv")
#       3 all_teams = pd.read_csv(r"./data/all_teams.csv")
#       4 all_events = pd.read_csv(r"./data/all_events.csv" , parse_dates= ["deadline_time"])
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./data/player_past_history/player_gameweek_history.csv' does not exist: b'./data/player_past_history/player_gameweek_history.csv'

# %%
def get_SMA(player_id , gw_period):
    player_data = player_gameweek_history[player_gameweek_history.player_id == player_id].set_index("gameweek_id")
    player_data = player_data[['total_points' , 'was_home' , 'opponent_strength', 'web_name']]

    player_name = player_data.iloc[0]['web_name']
    total_points = player_data.iloc[:,0]
    was_home = player_data.iloc[:,1]
    opponent_strength = player_data.iloc[:,2]

    
    # List to store moving average results
    SMA = list(range(0, len(total_points) - gw_period))
    SMA2 = list(range(0, len(total_points) - gw_period))

    # Compute moving average
    for ii in range(len(SMA)):
        # Previous gw index
        index = range(ii, ii + gw_period)
        # Get data for previous gw
        prev_gw = total_points.iloc[index]
        prev_gw2 = opponent_strength.iloc[index]

        # Sum previous gw
        summation = np.sum(prev_gw)
        summation2 = np.sum(prev_gw2)

        # Get average
        avg = summation/gw_period
        avg2 = summation2/gw_period
        # Save results to list
        SMA[ii] = avg
        SMA2[ii] = avg2
         
    # Define column label
    label = f"average_TP"
    label2 = f"average_OS"

    
    # Get corresponding gw for moving_avg
    gameweeks = total_points.index[gw_period:]
    gameweeks2 = opponent_strength.index[gw_period:]
    
    # Convert list into Pandas Series
    SMA = pd.Series(SMA, name = label, index = gameweeks)
    SMA2 = pd.Series(SMA2, name = label2, index = gameweeks2)

    player_data = pd.concat([player_data, SMA , SMA2] , axis = 1)
    player_data.dropna(inplace = True)

    return player_data , player_name

# %%
def correlation_graph(player_data , player_name):
    y = player_data['total_points']
    x = player_data['average_TP']

    slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)

    print("slope: %f    intercept: %f" % (slope, intercept))
    print("R-squared: %f" % r_value**2)
    print("")

    plt.plot(x, y, 'o', label='original data')
    plt.plot(x, intercept + slope*x, 'r', label='fitted line')
    plt.title(player_name)
    plt.legend()
    plt.show()

# %%
def main():
    player_data , player_name = get_SMA(180,5)
    correlation_graph(player_data , player_name)

main()
# Out:
# slope: 0.072261    intercept: 0.727004
# R-squared: 0.001332

# %%
df , name = get_SMA(100,5)
df
# Out:
#              total_points  was_home  opponent_strength  web_name  average_TP  \
# gameweek_id
# 6                       3      True                  2  Hendrick        1.60
# 7                       2     False                  2  Hendrick        2.20
# 8                      10      True                  3  Hendrick        2.60
# 9                       1     False                  3  Hendrick        4.40
# 10                      1      True                  4  Hendrick        4.60
# 11                      2     False                  3  Hendrick        3.40
# 12                      3      True                  2  Hendrick        3.20
# 13                      3     False                  3  Hendrick        3.40
# 14                      2      True                  3  Hendrick        2.00
# 15                      4      True                  5  Hendrick        2.20
# 16                      2     False                  4  Hendrick        2.80
# 17                      3      True                  3  Hendrick        2.80
# 18                      2     False                  2  Hendrick        2.80
# 19                      0     False                  3  Hendrick        2.60
# 20                      1      True                  4  Hendrick        2.20
# 21                      0      True                  2  Hendrick        1.60
# 22                      2     False                  4  Hendrick        1.20
# 23                      2      True                  3  Hendrick        1.00
# 24                      3     False                  4  Hendrick        1.00
# 25                      3      True                  4  Hendrick        1.60
# 26                      4     False                  3  Hendrick        2.00
# 27                      2      True                  2  Hendrick        2.80
# 28                      3     False                  3  Hendrick        2.80
# 29                      1      True                  4  Hendrick        3.00
# 39                      0     False                  5  Hendrick        2.60
# 40                      0      True                  3  Hendrick        2.00
# 41                      0     False                  3  Hendrick        1.20
# 42                      0      True                  3  Hendrick        0.80
# 43                      0     False                  2  Hendrick        0.20
# 44                      0     False                  5  Hendrick        0.00
# 45                      0      True                  4  Hendrick        0.00
# 46                      0     False                  2  Hendrick        0.00
# 47                      0      True                  2  Hendrick        0.00
#
#              average_OS
# gameweek_id
# 6                  3.60
# 7                  3.40
# 8                  3.00
# 9                  2.80
# 10                 2.40
# 11                 2.80
# 12                 3.00
# 13                 3.00
# 14                 3.00
# 15                 3.00
# 16                 3.20
# 17                 3.40
# 18                 3.60
# 19                 3.40
# 20                 3.40
# 21                 3.20
# 22                 2.80
# 23                 3.00
# 24                 3.20
# 25                 3.40
# 26                 3.40
# 27                 3.60
# 28                 3.20
# 29                 3.20
# 39                 3.20
# 40                 3.40
# 41                 3.40
# 42                 3.60
# 43                 3.60
# 44                 3.20
# 45                 3.20
# 46                 3.40
# 47                 3.20
