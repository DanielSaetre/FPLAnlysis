# %%
pip install pycaret
# Out:
# s://files.pythonhosted.org/packages/4a/e2/e588ab9298d4989ce7fdb2b97d18aac878d99dbdc379a4476a09d9271b68/tangled_up_in_unicode-0.0.6-py3-none-any.whl
# Collecting confuse>=1.0.0 (from pandas-profiling>=2.3.0->pycaret)
#   Using cached https://files.pythonhosted.org/packages/b5/6d/bedc0d1068bd244cee05843313cbec6cebb9f01f925538269bababc6d887/confuse-1.3.0-py2.py3-none-any.whl
# Collecting missingno>=0.4.2 (from pandas-profiling>=2.3.0->pycaret)
#   Using cached https://files.pythonhosted.org/packages/2b/de/6e4dd6d720c49939544352155dc06a08c9f7e4271aa631a559dfbeaaf9d4/missingno-0.4.2-py3-none-any.whl
# Requirement already satisfied: astropy>=4.0 in c:\users\danie\anaconda3\lib\site-packages (from pandas-profiling>=2.3.0->pycaret) (4.0.1.post1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\danie\anaconda3\lib\site-packages (from pandas-profiling>=2.3.0->pycaret) (2.24.0)
# Collecting htmlmin>=0.1.12 (from pandas-profiling>=2.3.0->pycaret)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\danie\anaconda3\lib\site-packages (from pandas-profiling>=2.3.0->pycaret) (4.48.2)
# Requirement already satisfied: regex in c:\users\danie\anaconda3\lib\site-packages (from nltk->pycaret) (2020.7.14)
# Requirement already satisfied: click in c:\users\danie\anaconda3\lib\site-packages (from nltk->pycaret) (7.1.2)
# Requirement already satisfied: zope.interface in c:\users\danie\anaconda3\lib\site-packages (from DateTime>=4.3->pycaret) (5.1.0)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy->pycaret)
#   Using cached https://files.pythonhosted.org/packages/4f/7b/d77bc9bb101e113884b2d70a118e7ec8dcc9846a35a0e10d47ca37acdcbf/murmurhash-1.0.2-cp37-cp37m-win_amd64.whl
# Collecting blis<0.5.0,>=0.4.0 (from spacy->pycaret)
#   Using cached https://files.pythonhosted.org/packages/d5/7e/1981d5389b75543f950026de40a9d346e2aec7e860b2800e54e65bd46c06/blis-0.4.1-cp37-cp37m-win_amd64.whl
# Collecting plac<1.2.0,>=0.9.6 (from spacy->pycaret)
#   Using cached https://files.pythonhosted.org/packages/86/85/40b8f66c2dd8f4fd9f09d59b22720cffecf1331e788b8a0cab5bafb353d1/plac-1.1.3-py2.py3-none-any.whl
# Collecting catalogue<1.1.0,>=0.0.7 (from spacy->pycaret)
#   Using cached https://files.pythonhosted.org/packages/6c/f9/9a5658e2f56932e41eb264941f9a2cb7f3ce41a80cb36b2af6ab78e2f8af/catalogue-1.0.0-py2.py3-none-any.whl
# Collecting preshed<3.1.0,>=3.0.2 (from spacy->pycaret)
#   Using cached https://files.pythonhosted.org/packages/3c/5a/0d1b575ed40989d74fab25723083837c220246b25f3582917135cb32453f/preshed-3.0.2-cp37-cp37m-win_amd64.whl
# Collecting wasabi<1.1.0,>=0.4.0 (from spacy->pycaret)
#   Using cached https://files.pythonhosted.org/packages/1b/10/55f3cf6b52cc89107b3e1b88fcf39719392b377a3d78ca61da85934d0d10/wasabi-0.8.0-py3-none-any.whl
# Collecting cymem<2.1.0,>=2.0.2 (from spacy->pycaret)
#   Using cached https://files.pythonhosted.org/packages/84/d1/35eab0c8cc9fd9432becaf3e90144762b3201a45079e62c47a8ae8739763/cymem-2.0.3-cp37-cp37m-win_amd64.whl
# Collecting srsly<1.1.0,>=1.0.2 (from spacy->pycaret)
#   Using cached https://files.pythonhosted.org/packages/fd/31/edaf3cdb7fcb644a51c7a568bc62a8c8d7462e61fa79b090f4d12d73d39e/srsly-1.0.2-cp37-cp37m-win_amd64.whl
# Collecting thinc==7.4.1 (from spacy->pycaret)
#   Using cached https://files.pythonhosted.org/packages/8b/6f/7cd666630afeb9b85cbd23c75da76b61580e45a9fe1c19145e3f7675ffc8/thinc-7.4.1-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\danie\anaconda3\lib\site-packages (from ipywidgets->pycaret) (5.0.7)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\danie\anaconda3\lib\site-packages (from ipywidgets->pycaret) (3.5.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\danie\anaconda3\lib\site-packages (from ipywidgets->pycaret) (4.3.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\danie\anaconda3\lib\site-packages (from ipywidgets->pycaret) (5.3.4)
# Collecting databricks-cli>=0.8.7 (from mlflow->pycaret)
# Requirement already satisfied: pyyaml in c:\users\danie\anaconda3\lib\site-packages (from mlflow->pycaret) (5.1.2)
# Requirement already satisfied: entrypoints in c:\users\danie\anaconda3\lib\site-packages (from mlflow->pycaret) (0.3)
# Requirement already satisfied: gitpython>=2.1.0 in c:\users\danie\anaconda3\lib\site-packages (from mlflow->pycaret) (3.1.7)
# Collecting querystring-parser (from mlflow->pycaret)
# Collecting sqlalchemy<=1.3.13 (from mlflow->pycaret)
#   Downloading https://files.pythonhosted.org/packages/af/47/35edeb0f86c0b44934c05d961c893e223ef27e79e1f53b5e6f14820ff553/SQLAlchemy-1.3.13.tar.gz (6.0MB)
# Requirement already satisfied: Flask in c:\users\danie\anaconda3\lib\site-packages (from mlflow->pycaret) (1.1.2)
# Collecting alembic (from mlflow->pycaret)
# Collecting sqlparse (from mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/85/ee/6e821932f413a5c4b76be9c5936e313e4fc626b33f16e027866e1d60f588/sqlparse-0.3.1-py2.py3-none-any.whl
# Collecting docker>=4.0.0 (from mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/9e/8c/8d42dbd83679483db207535f4fb02dc84325fa78b290f057694b057fcd21/docker-4.3.1-py2.py3-none-any.whl
# Requirement already satisfied: protobuf>=3.6.0 in c:\users\danie\anaconda3\lib\site-packages (from mlflow->pycaret) (3.13.0)
# Requirement already satisfied: cloudpickle in c:\users\danie\anaconda3\lib\site-packages (from mlflow->pycaret) (1.6.0)
# Collecting prometheus-flask-exporter (from mlflow->pycaret)
# Collecting azure-storage-blob>=12.0 (from mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/60/dc/3c25aeab827266c019e13abc07f31b5f47d93f1b8548a417c81c89c9d021/azure_storage_blob-12.4.0-py2.py3-none-any.whl
# Requirement already satisfied: waitress; platform_system == "Windows" in c:\users\danie\anaconda3\lib\site-packages (from mlflow->pycaret) (1.4.4)
# Requirement already satisfied: gorilla in c:\users\danie\anaconda3\lib\site-packages (from mlflow->pycaret) (0.3.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\danie\anaconda3\lib\site-packages (from cufflinks>=0.17.0->pycaret) (0.3.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\danie\anaconda3\lib\site-packages (from gensim->pycaret) (2.1.0)
# Requirement already satisfied: Cython==0.29.14 in c:\users\danie\anaconda3\lib\site-packages (from gensim->pycaret) (0.29.14)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\danie\anaconda3\lib\site-packages (from IPython->pycaret) (3.0.6)
# Requirement already satisfied: pygments in c:\users\danie\anaconda3\lib\site-packages (from IPython->pycaret) (2.6.1)
# Requirement already satisfied: jedi>=0.10 in c:\users\danie\anaconda3\lib\site-packages (from IPython->pycaret) (0.17.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\danie\anaconda3\lib\site-packages (from IPython->pycaret) (0.4.3)
# Requirement already satisfied: decorator in c:\users\danie\anaconda3\lib\site-packages (from IPython->pycaret) (4.4.2)
# Requirement already satisfied: pickleshare in c:\users\danie\anaconda3\lib\site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: backcall in c:\users\danie\anaconda3\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: llvmlite>=0.29.0dev0 in c:\users\danie\anaconda3\lib\site-packages (from numba>=0.35->pyod->pycaret) (0.29.0)
# Requirement already satisfied: iniconfig in c:\users\danie\anaconda3\lib\site-packages (from pytest->pyLDAvis->pycaret) (1.0.1)
# Requirement already satisfied: py>=1.8.2 in c:\users\danie\anaconda3\lib\site-packages (from pytest->pyLDAvis->pycaret) (1.9.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\danie\anaconda3\lib\site-packages (from pytest->pyLDAvis->pycaret) (20.1.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\users\danie\anaconda3\lib\site-packages (from pytest->pyLDAvis->pycaret) (0.13.1)
# Requirement already satisfied: atomicwrites>=1.0; sys_platform == "win32" in c:\users\danie\anaconda3\lib\site-packages (from pytest->pyLDAvis->pycaret) (1.4.0)
# Requirement already satisfied: packaging in c:\users\danie\anaconda3\lib\site-packages (from pytest->pyLDAvis->pycaret) (20.4)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in c:\users\danie\anaconda3\lib\site-packages (from pytest->pyLDAvis->pycaret) (1.7.0)
# Requirement already satisfied: toml in c:\users\danie\anaconda3\lib\site-packages (from pytest->pyLDAvis->pycaret) (0.10.1)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\users\danie\anaconda3\lib\site-packages (from pytest->pyLDAvis->pycaret) (8.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\danie\anaconda3\lib\site-packages (from jinja2>=2.7.2->pyLDAvis->pycaret) (1.1.1)
# Requirement already satisfied: networkx>=2.4 in c:\users\danie\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling>=2.3.0->pycaret) (2.5)
# Collecting imagehash; extra == "type_image_path" (from visions[type_image_path]==0.4.4->pandas-profiling>=2.3.0->pycaret)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\danie\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling>=2.3.0->pycaret) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\danie\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling>=2.3.0->pycaret) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\danie\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling>=2.3.0->pycaret) (2.8)
# Requirement already satisfied: ipython-genutils in c:\users\danie\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\danie\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\danie\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (4.6.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\danie\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.0.1)
# Requirement already satisfied: jupyter-client in c:\users\danie\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in c:\users\danie\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.0.4)
# Collecting tabulate>=0.7.7 (from databricks-cli>=0.8.7->mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/c4/f4/770ae9385990f5a19a91431163d262182d3203662ea2b5739d0fcfc080f1/tabulate-0.8.7-py3-none-any.whl
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\danie\anaconda3\lib\site-packages (from gitpython>=2.1.0->mlflow->pycaret) (4.0.5)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\danie\anaconda3\lib\site-packages (from Flask->mlflow->pycaret) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\danie\anaconda3\lib\site-packages (from Flask->mlflow->pycaret) (1.0.1)
# Collecting python-editor>=0.3 (from alembic->mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Collecting Mako (from alembic->mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/a6/37/0e706200d22172eb8fa17d68a7ae22dec7631a0a92266634fb518a88a5b2/Mako-1.1.3-py2.py3-none-any.whl
# Collecting pywin32==227; sys_platform == "win32" (from docker>=4.0.0->mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/bb/23/00fe4fbf9963f3bcb34a443eba0d0283fc51e5887d4045552c87490394e4/pywin32-227-cp37-cp37m-win_amd64.whl
# Collecting websocket-client>=0.32.0 (from docker>=4.0.0->mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl
# Requirement already satisfied: prometheus-client in c:\users\danie\anaconda3\lib\site-packages (from prometheus-flask-exporter->mlflow->pycaret) (0.8.0)
# Collecting azure-core<2.0.0,>=1.6.0 (from azure-storage-blob>=12.0->mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/5b/e3/acb0c45c0b7afa33eca9fadb47f32cbfb95161e3719fcbe953d689b881bc/azure_core-1.8.0-py2.py3-none-any.whl
# Collecting msrest>=0.6.10 (from azure-storage-blob>=12.0->mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/d9/ed/8e1b75721ad983c1672cd968ad3ae374d2e94767edff6f0b72a15dfde933/msrest-0.6.18-py2.py3-none-any.whl
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\danie\anaconda3\lib\site-packages (from azure-storage-blob>=12.0->mlflow->pycaret) (3.0)
# Requirement already satisfied: boto3 in c:\users\danie\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim->pycaret) (1.14.48)
# Requirement already satisfied: boto in c:\users\danie\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim->pycaret) (2.49.0)
# Requirement already satisfied: wcwidth in c:\users\danie\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\danie\anaconda3\lib\site-packages (from jedi>=0.10->IPython->pycaret) (0.7.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\danie\anaconda3\lib\site-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest->pyLDAvis->pycaret) (3.1.0)
# Requirement already satisfied: PyWavelets in c:\users\danie\anaconda3\lib\site-packages (from imagehash; extra == "type_image_path"->visions[type_image_path]==0.4.4->pandas-profiling>=2.3.0->pycaret) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\danie\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret) (0.16.0)
# Requirement already satisfied: nbconvert in c:\users\danie\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\danie\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.8.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\danie\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (19.0.2)
# Requirement already satisfied: Send2Trash in c:\users\danie\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.5.0)
# Requirement already satisfied: smmap<4,>=3.0.1 in c:\users\danie\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->pycaret) (3.0.4)
# Collecting isodate>=0.6.0 (from msrest>=0.6.10->azure-storage-blob>=12.0->mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.6.10->azure-storage-blob>=12.0->mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in c:\users\danie\anaconda3\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.0->mlflow->pycaret) (1.14.2)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in c:\users\danie\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim->pycaret) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\danie\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim->pycaret) (0.10.0)
# Requirement already satisfied: botocore<1.18.0,>=1.17.48 in c:\users\danie\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim->pycaret) (1.17.48)
# Requirement already satisfied: bleach in c:\users\danie\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (3.1.5)
# Requirement already satisfied: testpath in c:\users\danie\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\danie\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.4.2)
# Requirement already satisfied: defusedxml in c:\users\danie\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\danie\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.8.4)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-storage-blob>=12.0->mlflow->pycaret)
#   Using cached https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl
# Requirement already satisfied: pycparser in c:\users\danie\anaconda3\lib\site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.1.4->azure-storage-blob>=12.0->mlflow->pycaret) (2.20)
# Requirement already satisfied: docutils<0.16,>=0.10 in c:\users\danie\anaconda3\lib\site-packages (from botocore<1.18.0,>=1.17.48->boto3->smart-open>=1.8.1->gensim->pycaret) (0.15.2)
# Requirement already satisfied: webencodings in c:\users\danie\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.1)
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (setup.py): started
#   Building wheel for sqlalchemy (setup.py): finished with status 'done'
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.13-cp37-cp37m-win_amd64.whl size=1171670 sha256=f1b4e3569cea3076db6b6e30e25053a2b3c996e1a5307f37d804243d0128e7d1
#   Stored in directory: C:\Users\danie\AppData\Local\pip\Cache\wheels\b3\35\98\4c9cb3fd63d21d5606b972dd70643769745adf60e622467b71
# Successfully built sqlalchemy
# Installing collected packages: mlxtend, suod, combo, pyod, funcy, pyLDAvis, graphviz, catboost, tangled-up-in-unicode, imagehash, visions, phik, confuse, missingno, htmlmin, pandas-profiling, murmurhash, blis, plac, catalogue, cymem, preshed, wasabi, srsly, thinc, spacy, wordcloud, textblob, yellowbrick, umap-learn, imbalanced-learn, datefinder, tabulate, databricks-cli, querystring-parser, sqlalchemy, python-editor, Mako, alembic, sqlparse, pywin32, websocket-client, docker, prometheus-flask-exporter, azure-core, isodate, oauthlib, requests-oauthlib, msrest, azure-storage-blob, mlflow, kmodes, pycaret
#   Found existing installation: SQLAlchemy 1.3.19
#     Uninstalling SQLAlchemy-1.3.19:
#       Successfully uninstalled SQLAlchemy-1.3.19
#   Found existing installation: pywin32 228
#     Uninstalling pywin32-228:
#       Successfully uninstalled pywin32-228
# Successfully installed Mako-1.1.3 alembic-1.4.2 azure-core-1.8.0 azure-storage-blob-12.4.0 blis-0.4.1 catalogue-1.0.0 catboost-0.24.1 combo-0.1.1 confuse-1.3.0 cymem-2.0.3 databricks-cli-0.11.0 datefinder-0.7.1 docker-4.3.1 funcy-1.14 graphviz-0.14.1 htmlmin-0.1.12 imagehash-4.1.0 imbalanced-learn-0.7.0 isodate-0.6.0 kmodes-0.10.2 missingno-0.4.2 mlflow-1.10.0 mlxtend-0.17.3 msrest-0.6.18 murmurhash-1.0.2 oauthlib-3.1.0 pandas-profiling-2.8.0 phik-0.10.0 plac-1.1.3 preshed-3.0.2 prometheus-flask-exporter-0.16.0 pyLDAvis-2.1.2 pycaret-2.0 pyod-0.8.1 python-editor-1.0.4 pywin32-227 querystring-parser-1.2.4 requests-oauthlib-1.3.0 spacy-2.3.2 sqlalchemy-1.3.13 sqlparse-0.3.1 srsly-1.0.2 suod-0.0.4 tabulate-0.8.7 tangled-up-in-unicode-0.0.6 textblob-0.15.3 thinc-7.4.1 umap-learn-0.4.6 visions-0.4.4 wasabi-0.8.0 websocket-client-0.57.0 wordcloud-1.8.0 yellowbrick-1.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: umap-learn 0.4.6 has requirement numba!=0.47,>=0.46, but you'll have numba 0.45.1 which is incompatible.

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"./data/2019-20/player_past_history/merged_data.csv" , parse_dates = ["kickoff_time"]) 
all_players = pd.read_csv(r"./data/2019-20/all_players.csv" , parse_dates= ["news_added"]) 

total_players = len(all_players)
orig_df = data
data = data[data.minutes != 0]
